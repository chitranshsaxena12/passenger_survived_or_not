# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import sklearn
from pandas import Series, DataFrame
from pylab import rcParams
from sklearn import preprocessing
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score
from sklearn.model_selection import GridSearchCV
from sklearn import tree
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

# %%
titanic_data = pd.read_csv("https://raw.githubusercontent.com/BigDataGal/Python-for-Data-Science/master/titanic-train.csv")
titanic_data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic_data["Pclass"].unique()
# Out:
# array([3, 1, 2], dtype=int64)

# %%
titanic_data["SibSp"].unique()
# Out:
# array([1, 0, 3, 4, 2, 5, 8], dtype=int64)

# %%
titanic_data["Parch"].unique()
# Out:
# array([0, 1, 2, 5, 3, 4, 6], dtype=int64)

# %%
titanic_data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
main_data = titanic_data.iloc[:,[1,2,4,5,6,7,9]]
main_data
# Out:
#      Survived  Pclass     Sex   Age  SibSp  Parch     Fare
# 0           0       3    male  22.0      1      0   7.2500
# 1           1       1  female  38.0      1      0  71.2833
# 2           1       3  female  26.0      0      0   7.9250
# 3           1       1  female  35.0      1      0  53.1000
# 4           0       3    male  35.0      0      0   8.0500
# ..        ...     ...     ...   ...    ...    ...      ...
# 886         0       2    male  27.0      0      0  13.0000
# 887         1       1  female  19.0      0      0  30.0000
# 888         0       3  female   NaN      1      2  23.4500
# 889         1       1    male  26.0      0      0  30.0000
# 890         0       3    male  32.0      0      0   7.7500
#
# [891 rows x 7 columns]

# %%
main_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  891 non-null    int64
#  1   Pclass    891 non-null    int64
#  2   Sex       891 non-null    object
#  3   Age       714 non-null    float64
#  4   SibSp     891 non-null    int64
#  5   Parch     891 non-null    int64
#  6   Fare      891 non-null    float64
# dtypes: float64(2), int64(4), object(1)
# memory usage: 48.9+ KB

# %%
main_data.isnull().sum()
# Out:
# Survived      0
# Pclass        0
# Sex           0
# Age         177
# SibSp         0
# Parch         0
# Fare          0
# dtype: int64

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# let's being some data analysis

# %% [markdown]
# # Missing Data

# %% [markdown]
# we can use seaborn to create a simple heatmap to see where we are missing data

# %%
sns.heatmap(main_data.isnull(),yticklabels=False,cbar=False,cmap="viridis")
# Out:
# <AxesSubplot:>

# %% [markdown]
# Roughly 20 percent of th age data is missing. The proportion of Age missing is likely small enough for
# reasonable replacement with some of imputation.

# %%
sns.set_style("whitegrid")
sns.countplot(x="Survived",data=main_data,palette="RdBu_r")
# Out:
# <AxesSubplot:xlabel='Survived', ylabel='count'>

# %%
sns.set_style("whitegrid")
sns.countplot(x="Survived",hue="Sex",data=main_data,palette="RdBu_r")
# Out:
# <AxesSubplot:xlabel='Survived', ylabel='count'>

# %%
sns.set_style("whitegrid")
sns.countplot(x="Survived",hue="Pclass",data=main_data,palette="RdBu_r")
# Out:
# <AxesSubplot:xlabel='Survived', ylabel='count'>

# %%
sns.displot(main_data["Age"].dropna(),kde=True,color="darkred",bins=30)

# %%
main_data["Age"].hist(bins=30,color="darkred",alpha=0.7)
# Out:
# <AxesSubplot:>

# %%
sns.countplot(x="SibSp",data=main_data)
# Out:
# <AxesSubplot:xlabel='SibSp', ylabel='count'>

# %%
main_data["Fare"].hist(color="green",bins=40,figsize=(8,4))
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# We want to fill in missing age data instead of just dropping the missing age data row. One way to do
# this is by filling in the mean age of all the passengers. However we can be smarter about this and
# check the average age by passenger class. for example:

# %%
plt.figure(figsize=(12,7))
sns.boxplot(x="Pclass",y="Age",data=main_data,palette="winter")
# Out:
# <AxesSubplot:xlabel='Pclass', ylabel='Age'>

# %%
def impute_age(cols):
    Age = cols[0]
    Pclass = cols[1]
    
    if pd.isnull(Age):
            
            if Pclass == 1:
                return 37
            elif Pclass == 2:
                return 29
            else:
                return 24
    else:
        return Age

# %% [markdown]
# Now apply that function

# %%
main_data["Age"] = main_data[["Age","Pclass"]].apply(impute_age,axis=1)
# Out:
# C:\Users\Windows\AppData\Local\Temp/ipykernel_14288/600401835.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   main_data["Age"] = main_data[["Age","Pclass"]].apply(impute_age,axis=1)

# %% [markdown]
# Now let's check that heat map again !

# %%
sns.heatmap(main_data.isnull(),yticklabels=False,cbar=False,cmap="viridis")
# Out:
# <AxesSubplot:>

# %%
main_data
# Out:
#      Survived  Pclass     Sex   Age  SibSp  Parch     Fare
# 0           0       3    male  22.0      1      0   7.2500
# 1           1       1  female  38.0      1      0  71.2833
# 2           1       3  female  26.0      0      0   7.9250
# 3           1       1  female  35.0      1      0  53.1000
# 4           0       3    male  35.0      0      0   8.0500
# ..        ...     ...     ...   ...    ...    ...      ...
# 886         0       2    male  27.0      0      0  13.0000
# 887         1       1  female  19.0      0      0  30.0000
# 888         0       3  female  24.0      1      2  23.4500
# 889         1       1    male  26.0      0      0  30.0000
# 890         0       3    male  32.0      0      0   7.7500
#
# [891 rows x 7 columns]

# %% [markdown]
# In sex column change all the male and female with 0 and 1

# %%
main_data.replace(to_replace ="male",value = 0,inplace=True)
main_data.replace(to_replace ="female",value = 1,inplace=True)
# Out:
# C:\Users\Windows\anaconda3\lib\site-packages\pandas\core\frame.py:5238: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().replace(

# %%
main_data
# Out:
#      Survived  Pclass  Sex   Age  SibSp  Parch     Fare
# 0           0       3    0  22.0      1      0   7.2500
# 1           1       1    1  38.0      1      0  71.2833
# 2           1       3    1  26.0      0      0   7.9250
# 3           1       1    1  35.0      1      0  53.1000
# 4           0       3    0  35.0      0      0   8.0500
# ..        ...     ...  ...   ...    ...    ...      ...
# 886         0       2    0  27.0      0      0  13.0000
# 887         1       1    1  19.0      0      0  30.0000
# 888         0       3    1  24.0      1      2  23.4500
# 889         1       1    0  26.0      0      0  30.0000
# 890         0       3    0  32.0      0      0   7.7500
#
# [891 rows x 7 columns]

# %% [markdown]
# Divide data into x (independent variable) and y (dependent variable)

# %%
x = main_data.drop("Survived",axis=1)
y = main_data["Survived"]

# %% [markdown]
# # Data Visualization

# %%
plt.figure(figsize=(20,25))
plot_number = 1
for column in x:
    if plot_number<18:
        plt.subplot(6,3,plot_number)
        sns.distplot(x[column])
        plt.xlabel(column,fontsize=20)
    plot_number+=1
plt.show()
# Out:
# C:\Users\Windows\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Windows\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
plt.figure(figsize=(20,25))
plot_number = 1
for column in x:
    if plot_number<18:
        plt.subplot(6,3,plot_number)
        sns.scatterplot(x[column],y)
        plt.xlabel(column,fontsize=20)
    plot_number+=1
plt.show()
# Out:
# C:\Users\Windows\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Windows\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Windows\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ...

# %%
plt.figure(figsize=(20,25))
plot_number = 1
for column in x:
    if plot_number<18:
        plt.subplot(6,3,plot_number)
        sns.boxplot(x[column])
        plt.xlabel(column,fontsize=20)
    plot_number+=1
plt.show()
# Out:
# C:\Users\Windows\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Windows\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Windows\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ...

# %% [markdown]
# # There are many outliers in Age and Fare columns but from outliers doesn't effect on decision tree

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
X_scaled = scaler.fit_transform(x)

# %%
new_data = pd.DataFrame(X_scaled,columns=['Pclass','Sex','Age','SibSp','Parch','Fare'])

# %%
new_data
# Out:
#        Pclass       Sex       Age     SibSp     Parch      Fare
# 0    0.827377 -0.737695 -0.533834  0.432793 -0.473674 -0.502445
# 1   -1.566107  1.355574  0.674891  0.432793 -0.473674  0.786845
# 2    0.827377  1.355574 -0.231653 -0.474545 -0.473674 -0.488854
# 3   -1.566107  1.355574  0.448255  0.432793 -0.473674  0.420730
# 4    0.827377 -0.737695  0.448255 -0.474545 -0.473674 -0.486337
# ..        ...       ...       ...       ...       ...       ...
# 886 -0.369365 -0.737695 -0.156107 -0.474545 -0.473674 -0.386671
# 887 -1.566107  1.355574 -0.760469 -0.474545 -0.473674 -0.044381
# 888  0.827377  1.355574 -0.382743  0.432793  2.008933 -0.176263
# 889 -1.566107 -0.737695 -0.231653 -0.474545 -0.473674 -0.044381
# 890  0.827377 -0.737695  0.221619 -0.474545 -0.473674 -0.492378
#
# [891 rows x 6 columns]

# %% [markdown]
# Now we are going to split our data into train and test data

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.25, random_state=123)

# %% [markdown]
# # Fit our model

# %%
decision_model = DecisionTreeClassifier()
decision_model.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
plt.figure(figsize=(20,25))
tree.plot_tree(decision_model,filled=True)
# Out:
# [Text(0.5111221805695565, 0.975, 'X[1] <= 0.5\ngini = 0.474\nsamples = 668\nvalue = [410, 258]'),
#  Text(0.2001677482358871, 0.925, 'X[2] <= 13.0\ngini = 0.309\nsamples = 430\nvalue = [348, 82]'),
#  Text(0.07358870967741936, 0.875, 'X[3] <= 2.5\ngini = 0.473\nsamples = 26\nvalue = [10, 16]'),
#  Text(0.0655241935483871, 0.825, 'gini = 0.0\nsamples = 16\nvalue = [0, 16]'),
#  Text(0.08165322580645161, 0.825, 'gini = 0.0\nsamples = 10\nvalue = [10, 0]'),
#  Text(0.3267467867943548, 0.875, 'X[0] <= 1.5\ngini = 0.273\nsamples = 404\nvalue = [338, 66]'),
#  Text(0.09778225806451613, 0.825, 'X[2] <= 36.5\ngini = 0.459\nsamples = 87\nvalue = [56, 31]'),
#  Text(0.04838709677419355, 0.775, 'X[5] <= 37.812\ngini = 0.495\nsamples = 29\nvalue = [13, 16]'),
#  Text(0.016129032258064516, 0.725, 'X[5] <= 15.644\ngini = 0.298\nsamples = 11\nvalue = [2, 9]'),
#  Text(0.008064516129032258, 0.675, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
# ...

# %%
y_pred = decision_model.predict(X_test)

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.7757847533632287

# %% [markdown]
# for increasing accuracy use grid search CV

# %%
parameter = {'criterion':['gini', 'entropy'],
             "splitter":['best', 'random'],
             "max_depth":[2,3,4,5,6]
    
}

# %%
clf = GridSearchCV(decision_model, parameter,cv=5)

# %%
clf.fit(X_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=DecisionTreeClassifier(),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [2, 3, 4, 5, 6],
#                          'splitter': ['best', 'random']})

# %%
clf.best_params_
# Out:
# {'criterion': 'gini', 'max_depth': 6, 'splitter': 'best'}

# %%
decision_model = DecisionTreeClassifier(criterion= 'gini', max_depth= 6, splitter= 'best')
decision_model.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(max_depth=6)

# %%
y_pred = decision_model.predict(X_test)

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.8295964125560538

# %% [markdown]
# # Evaluation

# %%
print(confusion_matrix(y_test, y_pred))
print(accuracy_score(y_test,y_pred))
print(classification_report(y_test,y_pred))
# Out:
# [[125  14]
#  [ 24  60]]
# 0.8295964125560538
#               precision    recall  f1-score   support
#
#            0       0.84      0.90      0.87       139
#            1       0.81      0.71      0.76        84
#
#     accuracy                           0.83       223
#    macro avg       0.82      0.81      0.81       223
# weighted avg       0.83      0.83      0.83       223

# %% [markdown]
# # AUC and ROC Curve

# %%
from sklearn import  metrics

# %%
metrics.plot_roc_curve(decision_model, X_test, y_test) 
plt.show()
# Out:
# C:\Users\Windows\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function plot_roc_curve is deprecated; Function :func:`plot_roc_curve` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: :meth:`sklearn.metric.RocCurveDisplay.from_predictions` or :meth:`sklearn.metric.RocCurveDisplay.from_estimator`.
#   warnings.warn(msg, category=FutureWarning)

# %% [markdown]
# # Dump our best model

# %%
import pickle

# %%
filename = "Finalised_model.pickle"
pickle.dump(decision_model,open(filename,"wb"))

# %%
model = pickle.load(open(filename,"rb"))

# %%
x
# Out:
#      Pclass  Sex   Age  SibSp  Parch     Fare
# 0         3    0  22.0      1      0   7.2500
# 1         1    1  38.0      1      0  71.2833
# 2         3    1  26.0      0      0   7.9250
# 3         1    1  35.0      1      0  53.1000
# 4         3    0  35.0      0      0   8.0500
# ..      ...  ...   ...    ...    ...      ...
# 886       2    0  27.0      0      0  13.0000
# 887       1    1  19.0      0      0  30.0000
# 888       3    1  24.0      1      2  23.4500
# 889       1    0  26.0      0      0  30.0000
# 890       3    0  32.0      0      0   7.7500
#
# [891 rows x 6 columns]

# %%
model.predict([[3,0,35,0,0,8.0500]])
# Out:
# C:\Users\Windows\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array([0], dtype=int64)
